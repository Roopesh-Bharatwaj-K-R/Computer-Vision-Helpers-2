# %%
import cv2
import cv_exp.basic
import cv_exp.basic as cv
import cv_exp.pupil_detection as pupil_detection
import cv_exp.draw as draw
import cv_exp.log as log
import cv_exp.take as take
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import os
from PIL import Image
import pandas as pd
from scipy.cluster.vq import kmeans, vq
# Out:
# 2022-03-23 13:48:16.067422: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
model_face_detection = '/home/roopesh/Desktop/MediaPipe_new_cv_exp/cv-exp-framework-master/data/models/face_detection_front.tflite'
model_face_landmarks ='/home/roopesh/Desktop/MediaPipe_new_cv_exp/cv-exp-framework-master/data/models/face_landmark.tflite'
model_iris_landmarks = '/home/roopesh/Desktop/MediaPipe_new_cv_exp/cv-exp-framework-master/data/models/iris_landmark.tflite'

iris_detector = pupil_detection.IrisDetectorMP(model_face_detection_path=model_face_detection,
                                                   model_face_landmarks_path=model_face_landmarks,
                                                   model_iris_landmarks_path=model_iris_landmarks)

# %%
import matplotlib.pyplot as plt
import plotly.express as px

def Mediapipe_Iris_Color(path):
    '''
    This function takes the image in path and Using Mediapipe calculates the Annular Mask of the images,
    then calculates the HSV color of Annular mask.
    and returns the dominant Iris colour percentage in a data frame.
    '''

#         path='/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg'
    image = cv2.imread(path)

#     plt.imshow(image)
#     plt.show()

    # conversion numpy array into rgb image to show

   
    image_bgr_rgb = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # converting from BGR to RGB
    
    out = image_bgr_rgb.copy()
    out_pupile = image_bgr_rgb.copy()

    result = iris_detector.detect(image_bgr_rgb)

    if not result is None:

        detected_pupils = result.detected_pupils,
        face_rect_detection = result.face_rect_detection_from_landmarks,
        face_rect_landmarks = result.face_rect_from_landmarks,
        face_landmarks = result.face_landmarks,
        face_rect_detection_from = result.face_rect_from_detection,
        face_landmarks_from_detection = result.face_landmarks_from_detection,
        left_iris_landmarks = result.left_iris_landmarks,
        left_eyelid_landmarks = result.left_eyelid_landmarks,
        right_iris_landmarks = result.right_iris_landmarks,
        right_eyelid_landmarks = result.right_eyelid_landmarks,
        left_iris_segmentation = result.left_iris_segmentation,
        right_iris_segmentation = result.right_iris_segmentation,
        eyes_landmarks = result.eyes_landmarks

        out_pupile_ = draw.draw_pupils(out_pupile, result.detected_pupils.left, result.detected_pupils.right, color_center = (255, 255, 255), color_contour = (255, 255, 255))
        out_pupile_ = draw.draw_rect(out_pupile_, result.face_rect_detection_from_landmarks, thickness=2, color=(255, 0, 0))
        out_pupile_ = draw.draw_list_pointd(out_pupile_, result.left_iris_landmarks,radius=3,color = (255, 255, 255))
       
        out_pupile_= draw.draw_contour(out_pupile_, result.left_iris_segmentation,  thickness=4,color=(0, 0, 255))
#             fig=px.imshow(out_, title='Out Image -Iris Segmentation')


        eldt_lid_tuple_to_list=[pointe_elements for point in left_eyelid_landmarks for pointe_elements in point]
        lef_eye_lid=[(pointe.x,pointe.y) for pointe in eldt_lid_tuple_to_list]
#             print(lef_eye_lid)

        point_0= (np.round(lef_eye_lid[0]))
        for p0x,p0y in [point_0]:
            pointx0,pointy0= p0x,p0y

        point_1= (np.round(lef_eye_lid[1]))
        for p1x,p1y in [point_1]:
            pointx1,pointy1= p1x,p1y 

        point_2= (np.round(lef_eye_lid[2]))
        for p2x,p2y in [point_2]:
            pointx2,pointy2= p2x,p2y

        point_3= (np.round(lef_eye_lid[3]))
        for p3x,p3y in [point_3]:
            pointx3,pointy3=  p3x,p3y 

        point_4= (np.round(lef_eye_lid[4]))
        for p4x,p4y in [point_4]:
            pointx4,pointy4= p4x,p4y

        point_5= (np.round(lef_eye_lid[5]))
        for p5x,p5y in [point_5]:
            pointx5,pointy5= p5x,p5y

        point_6= (np.round(lef_eye_lid[6]))
        for p6x,p6y in [point_6]:
            pointx6,pointy6= p6x,p6y

        point_7= (np.round(lef_eye_lid[7]))
        for p7x,p7y in [point_7]:
            pointx7,pointy7= p7x,p7y

        point_8= (np.round(lef_eye_lid[8]))
        for p8x,p8y in [point_8]:
            pointx8,pointy8= p8x,p8y

        point_9= (np.round(lef_eye_lid[9]))
        for p9x,p9y in [point_9]:
            pointx9,pointy9= p9x,p9y

        point_10= (np.round(lef_eye_lid[10]))
        for p10x,p10y in [point_10]:
            pointx10,pointy10= p10x,p10y

        point_11= (np.round(lef_eye_lid[11]))
        for p11x,p11y in [point_11]:
            pointx11,pointy11= p11x,p11y

        point_12= (np.round(lef_eye_lid[12]))
        for p12x,p12y in [point_12]:
            pointx12,pointy12= p12x,p12y

        point_13= (np.round(lef_eye_lid[13]))
        for p13x,p13y in [point_13]:
            pointx13,pointy13= p13x,p13y

        point_14= (np.round(lef_eye_lid[14]))
        for p14x,p14y in [point_14]:
            pointx14,pointy14= p14x,p14y

        window_name = out_pupile_
        text='0'
        org = int(pointx0),int(pointy0)
        font = cv2.FONT_HERSHEY_SIMPLEX
        color = (255,0,0)
        color1= (0,0,0)
        thickness = 6
        thickness2=1
        fontScale = 1


        out = cv2.putText(window_name, ".", (int(pointx0),int(pointy0)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx1),int(pointy1)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx2),int(pointy2)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx3),int(pointy3)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx4),int(pointy4)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx5),int(pointy5)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx6),int(pointy6)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx7),int(pointy7)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx8),int(pointy8)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx9),int(pointy9)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx10),int(pointy10)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx11),int(pointy11)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx12),int(pointy12)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx13),int(pointy13)),font,fontScale,color ,thickness, cv2.LINE_AA )
        out = cv2.putText(window_name, ".", (int(pointx14),int(pointy14)),font,fontScale,color ,thickness, cv2.LINE_AA )

        out = cv2.putText(window_name, "0", ((int(pointx0)+15),int((pointy0)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "1", ((int(pointx1)+15),int((pointy1)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "2", ((int(pointx2)+15),int((pointy2)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "3", ((int(pointx3)+15),int((pointy3)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "4", ((int(pointx4)+15),int((pointy4)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "5", ((int(pointx5)+15),int((pointy5)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "6", ((int(pointx6)+15),int((pointy6)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "7", ((int(pointx7)+15),int((pointy7)+15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "8", ((int(pointx8)-15),int((pointy8)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "9", ((int(pointx9)-15),int((pointy9)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "10", ((int(pointx10)-15),int((pointy10)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "11", ((int(pointx11)-15),int((pointy11)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "12", ((int(pointx12)-15),int((pointy12)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "13", ((int(pointx13)-15),int((pointy13)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )
        out = cv2.putText(window_name, "14", ((int(pointx14)-15),int((pointy14)-15)),font,fontScale,color1 ,thickness2, cv2.LINE_AA )

        out_pipile_1 = cv2.cvtColor(out_pupile_, cv2.COLOR_BGR2RGB) 

        cv2.imwrite(f'/home/roopesh/Desktop/new_cvexp_results/V2.0/Iris_original_eyelid_/{file}',out_pipile_1)

        return out_pipile_1
    else:
        print('NOT detected :', file)
            
       
if __name__ == '__main__':
    
   images_files_dir = '/home/roopesh/Desktop/new_cvexp_results/V2.0/mix/'
#    images_files_dir= '/home/roopesh/Desktop/new_cvexp_results/V2.0/New_Blue_Eyes/Blue_Iris_Training_Image/' # Directory of the images

   files = os.listdir(images_files_dir)
   # sorted_file=sorted(files, key=lambda x : int(x[5:-4]))
   for idx, file in enumerate( files):
        image_path = images_files_dir + file
        # print('debug', file)
        mediapipe_iris_color_chart = Mediapipe_Iris_Color(image_path)           # Calling the Mediapipe_Iris_Color(image_path)
#         print(mediapipe_iris_color_chart)
# Out:
# NOT detected :[2022-03-24 10:49:04.526] [info] no detection
#  image822.jpg
# NOT detected :[2022-03-24 10:49:04.827] [info] no detection
#  image808.jpg
# NOT detected :[2022-03-24 10:49:06.353] [info] no detection
#  image798.jpg
# NOT detected :[2022-03-24 10:49:06.530] [info] no detection
#  image879.jpg
# NOT detected :[2022-03-24 10:49:07.150] [info] no detection
#  image401.jpg
# NOT detected :[2022-03-24 10:49:07.970] [info] no detection
#  image812.jpg
# NOT detected :[2022-03-24 10:49:08.089] [info] no detection
#  image807.jpg
# NOT detected :[2022-03-24 10:49:10.079] [info] no detection
#  image823.jpg
# NOT detected :[2022-03-24 10:49:10.773] [info] no detection
#  image889.jpg
# NOT detected :[2022-03-24 10:49:10.971] [info] no detection
#  image133.jpg
# NOT detected :[2022-03-24 10:49:11.206] [info] no detection
#  image806.jpg
# NOT detected :[2022-03-24 10:49:11.823] [info] no detection
#  image705.jpg
# NOT detected :[2022-03-24 10:49:11.967] [info] no detection
#  image888.jpg
# NOT detected :[2022-03-24 10:49:13.245] [info] no detection
#  image848.jpg
# NOT detected :[2022-03-24 10:49:13.431] [info] no detection
#  image880.jpg
# NOT detected :[2022-03-24 10:49:13.955] [info] no detection
#  front (3).jpg
# NOT detected :[2022-03-24 10:49:14.386] [info] no detection
#  image826.jpg
# NOT detected :[2022-03-24 10:49:14.532] [info] no detection
#  image839.jpg
# NOT detected :[2022-03-24 10:49:17.127] [info] no detection
#  image900.jpg
# NOT detected :[2022-03-24 10:49:21.406] [info] no detection
#  image917.jpg
# NOT detected :[2022-03-24 10:49:21.635] [info] no detection
#  image817.jpg
# NOT detected :[2022-03-24 10:49:22.600] [info] no detection
#  image809.jpg
# NOT detected :[2022-03-24 10:49:22.810] [info] no detection
#  image691.jpg
# NOT detected : image873.jpg
# NOT detected :[2022-03-24 10:49:23.430] [info] no detection
#  front.jpg
# NOT detected :[2022-03-24 10:49:24.032] [info] no detection
#  image861.jpg
# NOT detected :[2022-03-24 10:49:24.929] [info] no detection
#  image864.jpg
# NOT detected : image811.jpg
# NOT detected :[2022-03-24 10:49:25.233] [info] no detection
#  image577.jpg
# NOT detected :[2022-03-24 10:49:26.036] [info] no detection
#  image252.jpg
# NOT detected :[2022-03-24 10:49:26.271] [info] no detection
#  image881.jpg
# NOT detected :[2022-03-24 10:49:27.267] [info] no detection
#  image860.jpg
# NOT detected :[2022-03-24 10:49:27.656] [info] no detection
#  image495.jpg
# NOT detected :[2022-03-24 10:49:27.804] [info] no detection
#  image831.jpg
# NOT detected : image815.jpg
# [2022-03-24 10:49:29.060] [info] no detection
# NOT detected : image786.jpg
# NOT detected : image886.jpg
# NOT detected :[2022-03-24 10:49:29.832] [info] no detection
#  front(36).jpg
# NOT detected :[2022-03-24 10:49:30.463] [info] no detection
#  front (25).jpg
# NOT detected :[2022-03-24 10:49:30.610] [info] no detection
#  image909.jpg
# NOT detected :[2022-03-24 10:49:31.412] [info] no detection
#  image595.jpg
# NOT detected :[2022-03-24 10:49:33.110] [info] no detection
#  front (6).jpg
# NOT detected :[2022-03-24 10:49:34.704] [info] no detection
#  image724.jpg
# NOT detected :[2022-03-24 10:49:35.705] [info] no detection
#  image784.jpg
# NOT detected :[2022-03-24 10:49:37.500] [info] no detection
#  image690.jpg
# NOT detected :[2022-03-24 10:49:38.021] [info] no detection
#  front (31).jpg
# NOT detected :[2022-03-24 10:49:38.633] [info] no detection
#  front (10).jpg

# %% [markdown]
# <!-- Extract Left eye lid landmarks -->
