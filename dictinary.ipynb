# %%
dict={'File_name': {'Upper_Third': '/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg',
  'Middle_Third': '/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg',
  'Lower_Third': '/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg'},
 'Blue': {'Upper_Third': 50, 'Middle_Third': 0, 'Lower_Third':50},
 'Green': {'Upper_Third': 0, 'Middle_Third': 0, 'Lower_Third': 0},
 'Brown': {'Upper_Third': 0, 'Middle_Third': 0, 'Lower_Third': 0},
 'Other': {'Upper_Third': 50, 'Middle_Third': 0, 'Lower_Third': 50}}

# %%
print(dict)
# Out:
# {'File_name': {'Upper_Third': '/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg', 'Middle_Third': '/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg', 'Lower_Third': '/home/roopesh/Desktop/New_Corpus/Brown/front (3).jpg'}, 'Blue': {'Upper_Third': 50, 'Middle_Third': 0, 'Lower_Third': 50}, 'Green': {'Upper_Third': 0, 'Middle_Third': 0, 'Lower_Third': 0}, 'Brown': {'Upper_Third': 0, 'Middle_Third': 0, 'Lower_Third': 0}, 'Other': {'Upper_Third': 50, 'Middle_Third': 0, 'Lower_Third': 50}}

# %%
import pandas as pd
def print1(dict):
    dict1=dict
    
    file ='empty'

# Upper, Lower, Middle_Third to check +/-5% of the dominant color

    Blue_All_Equal= check_all(dict1['Blue']['Upper_Third'], dict1['Blue']['Middle_Third'], dict1['Blue']['Lower_Third'])
    Brown_All_Equal= check_all(dict1['Brown']['Upper_Third'], dict1['Brown']['Middle_Third'], dict1['Brown']['Lower_Third'])
    Green_All_Equal= check_all(dict1['Green']['Upper_Third'], dict1['Green']['Middle_Third'], dict1['Green']['Lower_Third'])
    Other_All_Equal= check_all(dict1['Other']['Upper_Third'], dict1['Other']['Middle_Third'], dict1['Other']['Lower_Third'])

    # Upper and Middle Third all lie within +/-5% of dominant color

    Blue_Upper_Middle_Equal = check_5Percent_range(dict1['Blue']['Upper_Third'], dict1['Blue']['Middle_Third'])
    Green_Upper_Middle_Equal = check_5Percent_range(dict1['Green']['Upper_Third'], dict1['Green']['Middle_Third'])
    Brown_Upper_Middle_Equal = check_5Percent_range(dict1['Brown']['Upper_Third'], dict1['Brown']['Middle_Third'])
    Other_Upper_Middle_Equal = check_5Percent_range(dict1['Other']['Upper_Third'], dict1['Other']['Middle_Third'])

    print("Blue_All_Equal: ", Blue_All_Equal, "Brown_All_Equal: ", Brown_All_Equal, "Green_All_Equal: ", Green_All_Equal, "Other_All_Equal: ", Other_All_Equal)
    print("Blue_Upper_Middle_Equal: ", Blue_Upper_Middle_Equal, "Green_Upper_Middle_Equal: ", Green_Upper_Middle_Equal, "Brown_Upper_Middle_Equal: ", Brown_Upper_Middle_Equal, "Other_Upper_Middle_Equal: ", Other_Upper_Middle_Equal)


    Upper_Middle = Blue_Upper_Middle_Equal is True and \
                   Green_Upper_Middle_Equal is True and \
                   Brown_Upper_Middle_Equal is True and \
                   Other_Upper_Middle_Equal is True

    print("Upper_Middle1: ", Upper_Middle)



    # Middle and Lower Third alone lie within +/-5% of dominant color

    Blue_Middle_Lower_Equal = check_5Percent_range(dict1['Blue']['Lower_Third'], dict1['Blue']['Middle_Third'])
    Green_Middle_Lower_Equal = check_5Percent_range(dict1['Green']['Lower_Third'], dict1['Green']['Middle_Third'])
    Brown_Middle_Lower_Equal = check_5Percent_range(dict1['Brown']['Lower_Third'], dict1['Brown']['Middle_Third'])
    Other_Middle_Lower_Equal = check_5Percent_range(dict1['Other']['Lower_Third'], dict1['Other']['Middle_Third'])


    print("Blue_Middle_Lower_Equal: ", Blue_Middle_Lower_Equal, "Green_Middle_Lower_Equal: ", Green_Middle_Lower_Equal, "Brown_Middle_Lower_Equal: ", Brown_Middle_Lower_Equal, "Other_Middle_Lower_Equal: ", Other_Middle_Lower_Equal)



    Middle_Lower = (Blue_Middle_Lower_Equal is True and
                    Green_Middle_Lower_Equal is True and
                    Brown_Middle_Lower_Equal is True and
                    Other_Middle_Lower_Equal is True)

    print("Middle_Lower1: ", Middle_Lower)


    # 1. Upper and Lower all lie within +/-5% of dominant color

    Blue_Upper_Lower_Equal = check_5Percent_range(dict1['Blue']['Upper_Third'], dict1['Blue']['Lower_Third'])
    Green_Upper_Lower_Equal = check_5Percent_range(dict1['Green']['Upper_Third'], dict1['Green']['Lower_Third'])
    Brown_Upper_Lower_Equal = check_5Percent_range(dict1['Brown']['Upper_Third'], dict1['Brown']['Lower_Third'])
    Other_Upper_Lower_Equal = check_5Percent_range(dict1['Other']['Upper_Third'], dict1['Other']['Lower_Third'])


    print("Blue_Upper_Lower_Equal: ", Blue_Upper_Lower_Equal, "Green_Upper_Lower_Equal: ", Green_Upper_Lower_Equal, "Brown_Upper_Lower_Equal: ", Brown_Upper_Lower_Equal, "Other_Upper_Lower_Equal: ", Other_Upper_Lower_Equal)

    Upper_Lower = Blue_Upper_Lower_Equal is True and \
                  Green_Upper_Lower_Equal is True and \
                  Brown_Upper_Lower_Equal is True and \
                  Other_Upper_Lower_Equal is True

    print("Upper_Lower: ", Upper_Lower)

    # Upper Middle Lower not lie within +/-5% of dominant color

    all_conflict = Blue_All_Equal is False and \
                   Green_All_Equal is False and\
                   Brown_All_Equal is False and \
                   Other_All_Equal is False

    print("all_conflict: ", all_conflict)

    # 2.  Upper Middle Lower alone lie.

    if Blue_All_Equal and Green_All_Equal and Brown_All_Equal and Other_All_Equal is True:


        data1 = [[file, str('No Conflicts')
                     , float((dict1['Blue']['Middle_Third']))
                     , float((dict1['Green']['Middle_Third']))
                     , float(dict1['Brown']['Middle_Third'])
                     , float(dict1['Other']['Middle_Third'])]]

        conflict_result = pd.DataFrame(data1, columns=['File_name:', 'Conflict_Type:', 'Blue:', 'Green:', 'Brown:','Other:']).T
        return conflict_result

    #  3. Upper and Middle Agree

    elif Upper_Middle is True and Middle_Lower is False and Upper_Lower is False: # Average


        data1 = [[file, str('Conflict with (Lower/Middle) and (Upper/Lower)')
                     , float(Average(dict1['Blue']['Upper_Third'], dict1['Blue']['Middle_Third']))
                     , float(Average(dict1['Green']['Upper_Third'], dict1['Green']['Middle_Third']))
                     , float(Average(dict1['Brown']['Upper_Third'], dict1['Brown']['Middle_Third']))
                     , float(Average(dict1['Other']['Upper_Third'], dict1['Other']['Middle_Third']))]]

        conflict_result = pd.DataFrame(data1, columns=['File_name:', 'Conflict_Type:', 'Blue:', 'Green:', 'Brown:','Other:']).T
        return conflict_result

    # 3.1 Middle and Lower Agree
    elif Middle_Lower is not False and Upper_Lower is False and Upper_Middle is False:  # Average
 

        data1 = [[file, str('Conflict with (Upper/Middle) and (Upper/Lower)')
                     , float(Average(dict1['Blue']['Middle_Third'], dict1['Blue']['Lower_Third']))
                     , float(Average(dict1['Green']['Middle_Third'], dict1['Green']['Lower_Third']))
                     , float(Average(dict1['Brown']['Middle_Third'], dict1['Brown']['Lower_Third']))
                     , float(Average(dict1['Other']['Middle_Third'], dict1['Other']['Lower_Third']))]]

        conflict_result = pd.DataFrame(data1, columns=['File_name:', 'Conflict_Type:', 'Blue:', 'Green:', 'Brown:','Other:']).T
        return conflict_result

    # 4 Upper, Middle, Bottom -Conflict

    elif all_conflict is False:    # weighted Average
   


        data1 = [[file, str('All_conflict1')
                     , float(weighted_Average(dict1['Blue']['Upper_Third'], dict1['Blue']['Lower_Third'], dict1['Blue']['Middle_Third']))
                     , float(weighted_Average(dict1['Green']['Upper_Third'], dict1['Green']['Lower_Third'], dict1['Green']['Middle_Third']))
                     , float(weighted_Average(dict1['Brown']['Upper_Third'], dict1['Brown']['Lower_Third'], dict1['Brown']['Middle_Third']))
                     , float(weighted_Average(dict1['Other']['Upper_Third'], dict1['Other']['Lower_Third'], dict1['Other']['Middle_Third']))]]

        conflict_result = pd.DataFrame(data1, columns=['File_name:', 'Conflict_Type:', 'Blue:', 'Green:', 'Brown:','Other:']).T
        return conflict_result

    # 5 Top and Bottom Agree but conflict in middle
    elif Upper_Lower is True and Middle_Lower is False and Upper_Middle is False:# weighted Average


        data1 = [[file, str('Conflict in Middle')
                     , float(weighted_Average(dict1['Blue']['Upper_Third'], dict1['Blue']['Lower_Third'], dict1['Blue']['Middle_Third']))
                     , float(weighted_Average(dict1['Green']['Upper_Third'], dict1['Green']['Lower_Third'], dict1['Green']['Middle_Third']))
                     , float(weighted_Average(dict1['Brown']['Upper_Third'], dict1['Brown']['Lower_Third'], dict1['Brown']['Middle_Third']))
                     , float(weighted_Average(dict1['Other']['Upper_Third'], dict1['Other']['Lower_Third'], dict1['Other']['Middle_Third']))]]

        conflict_result = pd.DataFrame(data1, columns=['File_name:', 'Conflict_Type:', 'Blue:', 'Green:', 'Brown:','Other:']).T
        return conflict_result


# Helper Function-1

def check_5Percent_range(x,y):
    flg = False
    if x < y:
        if x+(x*0.05) >= y:
            flg = True
    elif x > y:
        if x - (x*0.05) <= y:
            flg = True
    elif x==y:
        flg = True
    return flg

# Helper Function-2

def check_all(x,y,z):

    return check_5Percent_range(x,y) and check_5Percent_range( x,z) and check_5Percent_range(z,y)

# Helper Function-3

def Average(x,y):

    return (x/2 + y/2)

def weighted_Average(x,y,z):

    return ((1*(x + y) + 2 *(z))/4)

print(print1(dict))
# Out:
# Blue_All_Equal:  False Brown_All_Equal:  True Green_All_Equal:  True Other_All_Equal:  False
# Blue_Upper_Middle_Equal:  False Green_Upper_Middle_Equal:  True Brown_Upper_Middle_Equal:  True Other_Upper_Middle_Equal:  False
# Upper_Middle1:  False
# Blue_Middle_Lower_Equal:  False Green_Middle_Lower_Equal:  True Brown_Middle_Lower_Equal:  True Other_Middle_Lower_Equal:  False
# Middle_Lower1:  False
# Blue_Upper_Lower_Equal:  True Green_Upper_Lower_Equal:  True Brown_Upper_Lower_Equal:  True Other_Upper_Lower_Equal:  True
# Upper_Lower:  True
# all_conflict:  False
#                             0
# File_name:              empty
# Conflict_Type:  All_conflict1
# Blue:                    25.0
# Green:                    0.0
# Brown:                    0.0
# Other:                   25.0
